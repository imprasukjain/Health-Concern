# %%
pip install transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("medicalai/ClinicalGPT-base-zh")
model = AutoModelForCausalLM.from_pretrained("medicalai/ClinicalGPT-base-zh")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="Locutusque/gpt2-large-medical")

# %%
generated_text = pipe("What are the common symptoms of influenza?")
print(generated_text[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What are the common symptoms of influenza?  symptoms include fever, sore throat, cough, a sore throat that feels like a pin prick, runny nose, and aching muscles. The flu can be viral, bacterial, fungal or autoimmune

# %%
print("Chatbot: Hi, I'm a medical chatbot. You can ask me questions about medical topics. Type 'exit' to end the conversation.")

while True:
    user_input = input("You: ")
    
    if user_input.lower() == 'exit':
        print("Chatbot: Goodbye!")
        break
    
    # Generate a response
    generated_text = pipe(user_input)[0]['generated_text']
    
    print("Chatbot:", generated_text)
# Out:
# Chatbot: Hi, I'm a medical chatbot. You can ask me questions about medical topics. Type 'exit' to end the conversation.
# You:  I am Prasuk
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: I am Prasukta Chandrasekant who worked for National Dairy Products Limited in Gwalior. I have worked for the State Dairy Products Commission for nearly 9 years in two different departments. I am also a graduate of NRI University.
# You:  I want to know more about parkinson disease
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: I want to know more about parkinson disease. Is it known among the general population?" Yes
# You:  what is lung cancer?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: what is lung cancer?
#
# ...
